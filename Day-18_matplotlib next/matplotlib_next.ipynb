# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
plt.style.use('seaborn-pastel')

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  '_classic_test']

# %%
df = pd.DataFrame({
    'x' : [1,2,3,4,5],
    'y' : [3,5,7,9,2],
    'z' : [1,5,2,7,4]
})

# %matplotlib inline

# %%
fig = plt.figure('Gambar Day 18', figsize=(10,5)) # judul gambar (bisa dilihat di vscode)


label=['xx','xy','xz']
ax = plt.plot(df['x'], df[['x','y','z']])


plt.legend(label)
plt.xticks(np.arange(6), list('abcde'), rotation=30)

plt.title("Grafik Uji Coba")
plt.show()
plt.__file__ # menampilkan data matplotlib ada dimana, kemudian bisa edit style grafik di dalam folder 'mpl-data'
# Out:
# 'c:\\users\\nadian\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'

# %%
fig = plt.figure('Gambar Day 18', figsize=(15,10)) # judul gambar (bisa dilihat di vscode)
# plot 1 kiri 
# plt.style.use('seaborn-pastel')
ax = plt.subplot(2,2,1)
label=['xx','xy','xz']
ax = plt.plot(df['x'], df[['x','y','z']], linewidth=5)
ax = plt.scatter(df.x, df.y, zorder=3)
plot1 = plt
plot1.legend(label)
plot1.xticks(np.arange(6), list('abcde'), rotation=30)

plt.title("Grafik Uji Coba")

# plot 2 tengah
# plt.style.use('seaborn-paper')
ax2 = plt.subplot(2,2,2)
# label=['yx','yy','yz']
# ax2 = plt.plot(df['y'], df[['x','y','z']])
ax2 = plt.bar(df.x, df.y)

plt.legend(label)
plt.xticks( rotation=30)

plt.title("Grafik Uji Coba 2")

#plot kanan
# plt.style.use('seaborn-deep')
ax3 = plt.subplot(223)

label=['zx','zy','zz']
ax2 = plt.plot(df['z'], df[['x','y','z']], linewidth=5)

plt.legend(label)
plt.xticks(np.arange(6), list('abcde'), rotation=30)

plt.title("Grafik Uji Coba 3")


# plot 2 tengah
# plt.style.use('seaborn-paper')
ax2 = plt.subplot(2,2,4)
ax2 = plt.barh(df.x, df.y, color='pink',  edgecolor='k', linewidth=3, )

for i in df.y:
    plt.text(
        i+0.2, df[df['y']==i]['x'] + 0.5, i
    )

plt.legend(label)
plt.xticks( rotation=30)

plt.title("Grafik Uji Coba 2")
plot1.title("wohoo")

plt.suptitle("3 grafik uji coba di cell ini", y=.96)
plt.show()
plt.__file__ # menampilkan data matplotlib ada dimana, kemudian bisa edit style grafik di dalam folder 'mpl-data'
# Out:
# 'c:\\users\\nadian\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'

# %%
usia = [20,20,20,23,24,35,24,27,28,29,25,27,28,36,35,32,31,24,21]
partisi =[15,20,25,30,35,40,45]

plt.style.use('ggplot')
plt.hist(usia, partisi,)
plt.xticks(np.arange(15,65,5))

plt.show()

# %%
usia = [20,20,20,23,24,35,24,27,28,29,25,27,28,36,35,32,31,24,21]
partisi =[15,20,25,30,35,40,45]

plt.style.use('ggplot')
plt.hist(usia, partisi,
        histtype="stepfilled")
plt.xticks(np.arange(15,65,2))

plt.show()

# %%
usia = [20,20,20,23,24,35,24,27,28,29,25,27,28,36,35,32,31,24,21]
usia2 = [20,20,20,23,24,35,24,27,28,29,25,27,28,28,29,25,27,20,21]
partisi =[15,20,25,30,35,40,45]

plt.style.use('ggplot')
plt.hist([usia,usia2], partisi,
        histtype="barstacked"
        )
plt.xticks(np.arange(15,65,5))

plt.show()

# %%
usia = [20,20,20,23,24,35,24,27,28,29,25,27,28,36,35,32,31,24,21]
usia2 = [20,20,20,23,24,35,24,27,28,29,25,27,28,28,29,25,27,20,21]
partisi =[15,20,25,30,35,40,45]

plt.style.use('ggplot')
plt.hist([usia,usia2], partisi,
        histtype="bar"
        )
plt.xticks(np.arange(15,65,5))

plt.show()

# %%
usia = [20,20,20,23,24,35,24,27,28,29,25,27,28,36,35,32,31,24,21]
usia2 = [20,20,20,23,24,35,24,27,28,29,25,27,28,28,29,25,27,20,21]
partisi =[15,20,25,30,35,40,45]

plt.style.use('ggplot')
plt.hist([usia,usia2], partisi,
        histtype="step"
        )
plt.xticks(np.arange(15,65,5))

plt.show()

# %%
import matplotlib.image as mimg

# %%
gbr = mimg.imread('yutub.png')

# melihat dimensi gambar yang diload
gbr.shape
# (170, 170, 4) # 3 dimensi
# Out:
# (170, 170, 4)

# %%
fig = plt.figure('Gambar', figsize=(15,10)) # judul gambar (bisa dilihat di vscode)

ax = plt.subplot(3,3,1)
ax.imshow(gbr)


ax = plt.subplot(3,3,2)
gbr2 = gbr[:,:,1]
ax.imshow(gbr2, cmap='cool')

ax = plt.subplot(3,3,3)
gbr2 = gbr[:,:,0]
ax.imshow(gbr2, cmap='hot')
