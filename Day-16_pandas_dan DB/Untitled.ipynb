# %%
import pandas as pd

# %%
df = pd.read_csv('TLKM.JK.csv', parse_dates=['Date'])
df.head()
df.dtypes
# df.head(1)
# df.loc[0]
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
df[
    df['Close'] == 
    df['Close'].max()
]
# Out:
#           Date    Open    High     Low   Close  Adj Close     Volume
# 0   2019-06-05  3900.0  3900.0  3900.0  4470.0     3900.0          0
# 1   2019-06-06  3900.0  3900.0  3900.0  4470.0     3900.0          0
# 2   2019-06-07  3900.0  3900.0  3900.0  4470.0     3900.0          0
# 3   2019-06-10  4000.0  4060.0  3970.0  4470.0     4040.0  222522800
# 4   2019-06-11  4010.0  4060.0  4000.0  4470.0     4020.0   88861700
# 5   2019-06-12  3880.0  3950.0  3840.0  4470.0     3940.0  134724400
# 6   2019-06-13  3940.0  3990.0  3900.0  4470.0     3990.0  115734700
# 7   2019-06-14  4020.0  4050.0  3970.0  4470.0     3990.0   92466800
# 8   2019-06-17  3950.0  3970.0  3900.0  4470.0     3900.0   60851700
# 9   2019-06-18  3890.0  3990.0  3890.0  4470.0     3980.0   66112800
# 10  2019-06-19  4020.0  4120.0  4020.0  4470.0     4100.0  100210400
# 11  2019-06-20  4110.0  4110.0  4020.0  4470.0     4040.0   57673700
# 12  2019-06-21  4010.0  4040.0  3950.0  4470.0     4040.0  154049700
# ...

# %%
# contoh resample data
# df = df.set_index('Date')
df.head()

# mencari data perakhir bulan (M)
# mencari data perakhir minggu (W)
# mencari perkuartil (Q) per 3bulan 
# mencari pertahun (Y)
df['2019-09':'2019-11']['Close'].resample('Q').mean()
# Out:
# Date
# 2019-09-30    4266.666667
# 2019-12-31    4125.681818
# Freq: Q-DEC, Name: Close, dtype: float64

# %%
# mengatasi hari yang hiang ketika ada sabtu dan minggu libur

# 1. membuat data menjadi berurutan
df = df.sort_index()
df

#. 2. mengisi hari2 yang rumpang dengan NaN
df1 = df.resample('D').sum()
df1.head(10)
import numpy as np
[df1['Volume'] == np.nan]
# Out:
# [Date
#  2019-06-05    False
#  2019-06-06    False
#  2019-06-07    False
#  2019-06-08    False
#  2019-06-09    False
#  2019-06-10    False
#  2019-06-11    False
#  2019-06-12    False
#  2019-06-13    False
#  2019-06-14    False
#  2019-06-15    False
#  2019-06-16    False
#  2019-06-17    False
#  2019-06-18    False
#  2019-06-19    False
#  2019-06-20    False
#  2019-06-21    False
#  2019-06-22    False
#  2019-06-23    False
#  2019-06-24    False
#  2019-06-25    False
#  2019-06-26    False
#  2019-06-27    False
#  2019-06-28    False
#  2019-06-29    False
#  2019-06-30    False
#  2019-07-01    False
#  2019-07-02    False
#  2019-07-03    False
#  2019-07-04    False
#                ...
#  2019-11-07    False
#  2019-11-08    False
#  2019-11-09    False
#  2019-11-10    False
#  2019-11-11    False
#  2019-11-12    False
#  2019-11-13    False
#  2019-11-14    False
#  2019-11-15    False
#  2019-11-16    False
#  2019-11-17    False
#  2019-11-18    False
# ...

# %%
df2 = df1.fillna(method='ffill', axis=0)
df2.head(10)
# Out:
#               Open    High     Low   Close  Adj Close       Volume
# Date
# 2019-06-05  3900.0  3900.0  3900.0  3900.0     3900.0          0.0
# 2019-06-06  3900.0  3900.0  3900.0  3900.0     3900.0          0.0
# 2019-06-07  3900.0  3900.0  3900.0  3900.0     3900.0          0.0
# 2019-06-08  3900.0  3900.0  3900.0  3900.0     3900.0          0.0
# 2019-06-09  3900.0  3900.0  3900.0  3900.0     3900.0          0.0
# 2019-06-10  4000.0  4060.0  3970.0  4040.0     4040.0  222522800.0
# 2019-06-11  4010.0  4060.0  4000.0  4020.0     4020.0   88861700.0
# 2019-06-12  3880.0  3950.0  3840.0  3940.0     3940.0  134724400.0
# 2019-06-13  3940.0  3990.0  3900.0  3990.0     3990.0  115734700.0
# 2019-06-14  4020.0  4050.0  3970.0  3990.0     3990.0   92466800.0
