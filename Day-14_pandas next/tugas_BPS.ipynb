# %% [markdown]
# # STUDI KASUS DATA BPS
#  Provinsi dengan desa terbanyak di th 03, 05, 08, 11, 14, 18
#  Provinsi dengan desa tersedikit di th 03, 05, 08, 11, 14,18

# %%
import pandas as pd
import numpy as np
import xlrd

# %%
# === mengenali NaN yang abjednya '-'
df = pd.read_excel('my-bps-file.xlsx', skiprows=3, na_values = ['-'], skipfooter=1)
df.iloc[ :,:1]
seriProv = pd.Series(name="Provinsi")

seriProv = df.iloc[:,0]

# === mereplace NaN dengan 0
df.fillna(0, inplace=True)
df
# Out:
#               Unnamed: 0   2003   2005   2008   2011  2014  2018  2003.1  \
# 0                   ACEH  507.0  660.0  678.0  761.0   748   723  5229.0
# 1         SUMATERA UTARA  336.0  175.0  375.0  396.0   459   423  5043.0
# 2         SUMATERA BARAT   80.0   99.0  102.0  116.0   127   132   795.0
# 3                   RIAU  346.0  406.0  186.0  232.0   271   254  1279.0
# 4                  JAMBI   28.0   28.0   28.0   29.0    30    28  1161.0
# 5       SUMATERA SELATAN   16.0   19.0   22.0   34.0    29    25  2691.0
# 6               BENGKULU  134.0  157.0  166.0  182.0   186   184  1029.0
# 7                LAMPUNG  170.0  186.0  203.0  231.0   241   231  1958.0
# 8   KEP. BANGKA BELITUNG  122.0  105.0  137.0  163.0   166   160   195.0
# 9              KEP. RIAU    0.0    0.0  267.0  299.0   361   355     0.0
# 10           DKI JAKARTA   16.0   16.0   15.0   16.0    16    15   251.0
# 11            JAWA BARAT  219.0  193.0  217.0  217.0   227   221  5539.0
# ...

# %%
prov = df.iloc[ : , 0]
data = df.iloc[ : , 1 : ]

data['Provinsi'] = prov
data
kol = data.columns.tolist()
kol = kol[-1:] + kol[ :-1]
data[kol]
# Out:
#                 Provinsi   2003   2005   2008   2011  2014  2018  2003.1  \
# 0                   ACEH  507.0  660.0  678.0  761.0   748   723  5229.0
# 1         SUMATERA UTARA  336.0  175.0  375.0  396.0   459   423  5043.0
# 2         SUMATERA BARAT   80.0   99.0  102.0  116.0   127   132   795.0
# 3                   RIAU  346.0  406.0  186.0  232.0   271   254  1279.0
# 4                  JAMBI   28.0   28.0   28.0   29.0    30    28  1161.0
# 5       SUMATERA SELATAN   16.0   19.0   22.0   34.0    29    25  2691.0
# 6               BENGKULU  134.0  157.0  166.0  182.0   186   184  1029.0
# 7                LAMPUNG  170.0  186.0  203.0  231.0   241   231  1958.0
# 8   KEP. BANGKA BELITUNG  122.0  105.0  137.0  163.0   166   160   195.0
# 9              KEP. RIAU    0.0    0.0  267.0  299.0   361   355     0.0
# 10           DKI JAKARTA   16.0   16.0   15.0   16.0    16    15   251.0
# 11            JAWA BARAT  219.0  193.0  217.0  217.0   227   221  5539.0
# ...

# %%
tepiLaut = data.iloc[0:, 0:6]
bTepiLaut = data.iloc[0:,6:12]
f3 = tepiLaut.values + bTepiLaut.values
f3 = pd.DataFrame(f3)
f3['Provinsi'] = prov
f3

# tepiLaut.add(bTepiLaut, fill_value=0)
# tepiLaut
# Out:
#          0       1       2       3       4       5              Provinsi
# 0   5736.0  5968.0  6424.0  6483.0  6512.0  6508.0                  ACEH
# 1   5379.0  4915.0  5767.0  5797.0  6104.0  6132.0        SUMATERA UTARA
# 2    875.0   901.0   924.0  1033.0  1145.0  1275.0        SUMATERA BARAT
# 3   1625.0  1732.0  1604.0  1655.0  1835.0  1875.0                  RIAU
# 4   1189.0  1235.0  1303.0  1372.0  1551.0  1562.0                 JAMBI
# 5   2707.0  2778.0  3079.0  3186.0  3237.0  3262.0      SUMATERA SELATAN
# 6   1163.0  1224.0  1351.0  1509.0  1532.0  1514.0              BENGKULU
# 7   2128.0  2191.0  2339.0  2464.0  2632.0  2654.0               LAMPUNG
# 8    317.0   321.0   344.0   361.0   381.0   391.0  KEP. BANGKA BELITUNG
# 9      0.0     0.0   326.0   353.0   415.0   416.0             KEP. RIAU
# 10   267.0   267.0   267.0   267.0   267.0   267.0           DKI JAKARTA
# 11  5758.0  5808.0  5871.0  5905.0  5962.0  5957.0            JAWA BARAT
# ...

# %%
maxDesa = list(map(lambda col : f3[f3[col] == f3[col].max()]['Provinsi'], range(6)))
maxDesa 
# for i in range(len(maxDesa)):
#     print(maxDesa[i])
#     print("----------------------------------------")
# Out:
# [12    JAWA TENGAH
#  Name: Provinsi, dtype: object, 12    JAWA TENGAH
#  Name: Provinsi, dtype: object, 12    JAWA TENGAH
#  Name: Provinsi, dtype: object, 12    JAWA TENGAH
#  Name: Provinsi, dtype: object, 12    JAWA TENGAH
#  Name: Provinsi, dtype: object, 12    JAWA TENGAH
#  Name: Provinsi, dtype: object]

# %%
# minDesa = list(map(lambda col : f3[f3[col] == f3[col].min()]['Provinsi'] , range(6)))
# freduce = f3.dropna('0')
# freduce = f3[f3[2003]!=0]
# f3[f3[0] != 0]
# freduce = f3[(f3[0] != 0) & (f3[1] != 0) & (f3[2] != 0) & (f3[3] != 0) & (f3[4] != 0) & (f3[5] != 0)]
freduce = f3
# minDesa = list(map(lambda col : freduce[freduce[col] == freduce[col].min()] , range(6)))

def aboveNol(seri):
    atasNol = freduce[freduce[seri] > 0]
    atasNol
    return freduce[ freduce[seri] == atasNol[seri].min() ]

minDesa = list(map(aboveNol, range(6)))
minDesa
# for i in minDesa:
#     print(i)
#     print("----------------------------------------")
# Out:
# [        0      1      2      3      4      5     Provinsi
#  10  267.0  267.0  267.0  267.0  267.0  267.0  DKI JAKARTA,
#          0      1      2      3      4      5     Provinsi
#  10  267.0  267.0  267.0  267.0  267.0  267.0  DKI JAKARTA,
#          0      1      2      3      4      5     Provinsi
#  10  267.0  267.0  267.0  267.0  267.0  267.0  DKI JAKARTA,
#          0      1      2      3      4      5     Provinsi
#  10  267.0  267.0  267.0  267.0  267.0  267.0  DKI JAKARTA,
#          0      1      2      3      4      5     Provinsi
#  10  267.0  267.0  267.0  267.0  267.0  267.0  DKI JAKARTA,
#          0      1      2      3      4      5     Provinsi
#  10  267.0  267.0  267.0  267.0  267.0  267.0  DKI JAKARTA]

# %% [markdown]
# ## Pandas Visualization
#
# Matplotlib has style sheets you can use to make your plots look a little nicer. These style sheets include plot_bmh, plot_fivethirtyeight, plot_ggplot and more.
#
# They basically create a set of style rules that your plots follow. They make all your plots have the same look and feel more professional.
#
# Here is how to use them.
#
# Before plt.style.use() your plots look like this:
# ![image.png](attachment:image.png)

# %%
import numpy as np
# %matplotlib inline

# %%
f3[0].hist()

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
f3[0].hist()

# %%
plt.style.use('bmh')
f3[[0,1,2,3,4,5]].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023B62D4A4E0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023B62EB44E0>]], dtype=object)

# %%
plt.style.use('dark_background')
f3[[0,1]].hist()
# f3[].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023B62591F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000023B62662DD8>]], dtype=object)

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-137-99e0464ca48a> in <module>()
# ----> 1 df = pd.read_csv('Salaries.csv')
#       2 df
#
# ...
